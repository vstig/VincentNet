# %%
# %load_ext autotime
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

from vincentnet.neural_net import NeuralNetwork
# Out:
# time: 1.38 ms

# %%
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D)) # data matrix (each row = single example)
y = np.zeros(N*K, dtype='uint8') # class labels
for j in xrange(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
  X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y[ix] = j
# lets visualize the data:
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.show()
# Out:
# time: 228 ms

# %%
#D, k, layers, step_size = 1e-0, reg = 1e-3):

nn = NeuralNetwork(D=2, k=3, layers=[50])

for s in range(10000):
    l = nn.step(X, y)
    
    if s%1000==0:
        print 'Loss at step {}: {}'.format(s, l)
        
        
nn.get_accuracy(X, y)
# Out:
# Loss at step 0: 1.09861643672
# Loss at step 1000: 0.269737091886
# Loss at step 2000: 0.258893485991
# Loss at step 3000: 0.260122082202
# Loss at step 4000: 0.26176698725
# Loss at step 5000: 0.264287314366
# Loss at step 6000: 0.264663845529
# Loss at step 7000: 0.258543392475
# Loss at step 8000: 0.260479788159
# Loss at step 9000: 0.258542501642
# 0.98
# time: 4.34 s

# %%
#Add another hidden layer, make see if backprop setup properly

nn = NeuralNetwork(D=2, k=3, layers=[50, 25], step_size = .05, reg = .001)

for s in range(20000):
    l = nn.step(X, y)
    
    if s%1000==0:
        print 'Loss at step {}: {}'.format(s, l)
        
        
nn.get_accuracy(X, y)
# Out:
# Loss at step 0: 1.09867886244
# Loss at step 1000: 1.09864732267
# Loss at step 2000: 1.09857222191
# Loss at step 3000: 1.09790809736
# Loss at step 4000: 0.906369272999
# Loss at step 5000: 0.731176060193
# Loss at step 6000: 0.413059322931
# Loss at step 7000: 0.21451231561
# Loss at step 8000: 0.185257129839
# Loss at step 9000: 0.176444829392
# Loss at step 10000: 0.172649788329
# Loss at step 11000: 0.170761634222
# Loss at step 12000: 0.169531349873
# Loss at step 13000: 0.168754882986
# Loss at step 14000: 0.16818656574
# Loss at step 15000: 0.167738303175
# Loss at step 16000: 0.167357827225
# Loss at step 17000: 0.167023646878
# Loss at step 18000: 0.166682333504
# Loss at step 19000: 0.166286875268
# 0.9933333333333333
# time: 13.8 s

# %%
plt.scatter(X[:, 0], X[:, 1], c=nn.predict(X), s=40, cmap=plt.cm.Spectral)
# Out:
# time: 208 ms

# %%
nn.predict(X)!=y
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...
